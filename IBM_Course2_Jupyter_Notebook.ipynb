# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Samuel Kwame Dassi**
#
# Student at the University of Cape Coast, Ghana

# %% [markdown]
# *I am interested in data science because it is relatively new in Ghana and Africa as a whole. I also want to contribute to effective and data driven decision making in organizations to propel the economic growth of the continent.*

# %% [markdown]
# ### In the next cell I explored the product of any two numbers

# %%
a = 5
b = 8
product = a*b
print(product)
# Out:
# 40

# %% [markdown]
#  - Watson Studio
#
#  [my linkedin profile](https://www.linkedin.com/in/samuel-kwame-dassi/)
#
#  ![ucc_the_ranking_snipets-11.jpg](attachment:6a85b3da-cd15-49b3-b787-bd68b3d00b6f.jpg)

# %% [markdown]
# The End!
